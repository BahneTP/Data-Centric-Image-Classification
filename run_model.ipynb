# %%
# %cd dcic
# !ls
# Out:
# /workspace/dcic
# Dockerfile  README.md  images  license.txt  requirements.txt  run.sh  src
# /usr/local/lib/python3.10/dist-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %% [markdown]
# # -------- Running --------

# %%
# execute on all datasets
# !python -m src.algorithms.active_learning --data_root /workspace/ --datasets Benthic,MiceBone,QualityMRI,Treeversity#6 --percentage_labeled_data 0 --number_annotations_per_image 0 --v_fold 1

# try out for individual datasets
# !python -m src.algorithms.active_learning --data_root /workspace/ --datasets QualityMRI --percentage_labeled_data 0 --number_annotations_per_image 0 --v_fold 1
# !python -m src.algorithms.active_learning --data_root /workspace/ --datasets Benthic --percentage_labeled_data 0 --number_annotations_per_image 0 --v_fold 1
# !python -m src.algorithms.active_learning --data_root /workspace/ --datasets MiceBone --percentage_labeled_data 0 --number_annotations_per_image 0 --v_fold 1
# !python -m src.algorithms.active_learning --data_root /workspace/ --datasets Treeversity#6 --percentage_labeled_data 0 --number_annotations_per_image 0 --v_fold 1
# Out:
# 2025-07-11 22:21:51.695277: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-11 22:21:51.712496: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752272511.732336  815667 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752272511.738432  815667 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %% [markdown]
# # -------- Evaluating --------

# %%
# execute on all datasets -> warning could be detected as non-interactive by google colab
#!python -m src.evaluation.evaluate --data_root /workspace --output_folder /workspace/output_datasets --folders *-random-01-0.50  --slices 1 --verbose 3

# try out for individual datasets
# !python -m src.evaluation.evaluate --data_root /workspace --output_folder /workspace/output_datasets --folders QualityMRI-active_learning-00-0.00 --slices 1 --verbose 3
# !python -m src.evaluation.evaluate --data_root /workspace --output_folder /workspace/output_datasets --folders Benthic-active_learning-00-0.00  --slices 1 --verbose 3
#!python -m src.evaluation.evaluate --data_root /workspace --output_folder /workspace/output_datasets --folders MiceBone-random-01-0.50  --slices 1 --verbose 3
#!python -m src.evaluation.evaluate --data_root /workspace --output_folder /workspace/output_datasets --folders Treeversity#6-random-01-0.50  --slices 1 --verbose 3
# Out:
# 2025-07-11 20:48:16.830148: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-11 20:48:16.847488: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752266896.867238  166245 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752266896.873228  166245 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
