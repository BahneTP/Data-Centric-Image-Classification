# %% [markdown]
# # -------- Running --------

# %%
# %cd dcic
# Out:
# /workspace/Data-Centric-Image-Classification/dcic
# /usr/local/lib/python3.10/dist-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# execute on all datasets
# !python -m src.algorithms.semantic_init_spreading --data_root /workspace/Data-Centric-Image-Classification/ --datasets Benthic,MiceBone,QualityMRI,Treeversity#6 --percentage_labeled_data 0 --number_annotations_per_image 0 --v_fold 1

# try out for individual datasets
# !python -m src.algorithms.semantic_init_spreading --data_root /workspace/Data-Centric-Image-Classification/ --datasets QualityMRI --percentage_labeled_data 0 --number_annotations_per_image 0 --v_fold 1
# !python -m src.algorithms.testdata_init_spreading --data_root /workspace/Data-Centric-Image-Classification/ --datasets Benthic --percentage_labeled_data 0 --number_annotations_per_image 0 --v_fold 1
# !python -m src.algorithms.testdata_init_spreading --data_root /workspace/Data-Centric-Image-Classification/ --datasets MiceBone --percentage_labeled_data 0 --number_annotations_per_image 0 --v_fold 1
# !python -m src.algorithms.testdata_init_spreading --data_root /workspace/Data-Centric-Image-Classification/ --datasets Treeversity#6 --percentage_labeled_data 0 --number_annotations_per_image 0 --v_fold 1
# Out:
# 2025-07-13 18:33:36.479204: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-13 18:33:36.494615: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752431616.512754  261254 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752431616.518099  261254 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %% [markdown]
# # Evaluation

# %%
# # execute on all datasets -> warning could be detected as non-interactive by google colab
# #!python -m src.evaluation.evaluate --data_root /workspace/Data-Centric-Image-Classification --output_folder /workspace/Data-Centric-Image-Classification/output_datasets --folders *-testdata_init_spreading-00-0.00  --slices 1 --verbose 3

# # try out for individual datasets
# !python -m src.evaluation.evaluate --data_root /workspace/Data-Centric-Image-Classification --output_folder /workspace/Data-Centric-Image-Classification/output_datasets --folders QualityMRI-testdata_init_spreading-00-0.00 --slices 1 --verbose 3
# !python -m src.evaluation.evaluate --data_root /workspace/Data-Centric-Image-Classification --output_folder /workspace/Data-Centric-Image-Classification/output_datasets --folders Benthic-testdata_init_spreading-00-0.00  --slices 1 --verbose 3
# # !python -m src.evaluation.evaluate --data_root /workspace/Data-Centric-Image-Classification --output_folder /workspace/Data-Centric-Image-Classification/output_datasets --folders MiceBone-testdata_init_spreading-00-0.00  --slices 1 --verbose 3
# # !python -m src.evaluation.evaluate --data_root /workspace/Data-Centric-Image-Classification --output_folder /workspace/Data-Centric-Image-Classification/output_datasets --folders Treeversity#6-testdata_init_spreading-00-0.00  --slices 1 --verbose 3
# Out:
# 2025-07-13 18:09:05.472008: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-13 18:09:05.487770: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752430145.505385  253911 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752430145.510908  253911 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
