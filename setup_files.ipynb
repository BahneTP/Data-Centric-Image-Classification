# %%
# !cd /workspace/Data-Centric-Image-Classification/dcic
# !ls
# !rm -R /workspace/dcic
# %cd /workspace/
# !git clone https://github.com/Emprime/dcic.git
# %cd dcic/
# !git checkout Lite
# Out:
# 'Data_Centric_Image_Classification_Labeling_Challenge_Quick_Start (1).ipynb'
#  dcic
#  evaluate_datasets
#  images
#  input_datasets
#  output_datasets
#  raw_datasets
#  run_model.ipynb
#  setup_files.ipynb
#  setup_versions.ipynb
# error: pathspec 'Lite' did not match any file(s) known to git

# %%
# !ls
# Out:
# 'Data_Centric_Image_Classification_Labeling_Challenge_Quick_Start (1).ipynb'
#  dcic
#  images
#  run_model.ipynb
#  setup_files.ipynb
#  setup_versions.ipynb

# %%
# %cd /workspace/Data-Centric-Image-Classification/dcic
# !python -m src.util.check_and_setup --data_root /workspace/Data-Centric-Image-Classification/
# Out:
# /workspace/Data-Centric-Image-Classification/dcic
# /usr/local/lib/python3.10/dist-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# Check & setup dataset Benthic
# 100%|██████████████████████████████████████| 4867/4867 [00:39<00:00, 124.46it/s]
# Calculated Channel mean and std [0.34728872821176654, 0.4001368786497493, 0.4110478166769662] [0.12869154897863097, 0.1364462674773899, 0.14258506692263376]
# Check & setup dataset MiceBone
# 100%|███████████████████████████████████████| 7240/7240 [01:43<00:00, 69.79it/s]
# Calculated Channel mean and std [0.4443307598418889, 0.4443307598418889, 0.4443307598418889] [0.24633541064133901, 0.24633541064133901, 0.24633541064133901]
# Check & setup dataset QualityMRI
# 100%|█████████████████████████████████████████| 310/310 [00:04<00:00, 68.11it/s]
# ...
